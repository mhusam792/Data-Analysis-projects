# %%
import pandas as pd
import os

# %%
folder_path = 'Sales_Data'

csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv') and file != 'all_data.csv']

concatenated_df = pd.DataFrame()

for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    concatenated_df = pd.concat([concatenated_df, df], ignore_index=True)

df = concatenated_df

# %%
df = pd.read_csv("Sales_Data/Sales_January_2019.csv")

# %% [markdown]
# # Dropping all rows with NA values for all columns

# %%
df.dropna(how="all", inplace=True)

# %% [markdown]
# # make columns easier to write

# %%
# df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.lower()
df.head()
# Out:
#   order_id                   product quantity_ordered price_each  \
# 0   141234                    iPhone                1        700
# 1   141235  Lightning Charging Cable                1      14.95
# 2   141236          Wired Headphones                2      11.99
# 3   141237          27in FHD Monitor                1     149.99
# 4   141238          Wired Headphones                1      11.99
#
#        order_date                       purchase_address
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301

# %% [markdown]
# # Transform columns datatypes to correct ones

# %%
df.dtypes
# Out:
# order_id            object
# product             object
# quantity_ordered    object
# price_each          object
# order_date          object
# purchase_address    object
# dtype: object

# %%
# New Datatypes
columns_data_types = ['object', 'category', 'int', 'float', 'datetime64', 'object']
convert_dict = {"product": 'category',
                "quantity_ordered": 'float',
                "price_each": 'float', 
                "order_date": 'datetime64[ns]'
                }

# Update df to not containing any of "Quantity Ordered" in quantity_ordered column
df = df[~(df.quantity_ordered == "Quantity Ordered")]
df = df.astype(convert_dict)

# %%
df.dtypes
# Out:
# order_id                    object
# product                   category
# quantity_ordered           float64
# price_each                 float64
# order_date          datetime64[ns]
# purchase_address            object
# dtype: object

# %%
df.head()
# Out:
#   order_id                   product  quantity_ordered  price_each  \
# 0   141234                    iPhone               1.0      700.00
# 1   141235  Lightning Charging Cable               1.0       14.95
# 2   141236          Wired Headphones               2.0       11.99
# 3   141237          27in FHD Monitor               1.0      149.99
# 4   141238          Wired Headphones               1.0       11.99
#
#            order_date                       purchase_address
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301

# %% [markdown]
# ### Splitting purchase_address column to 4 columns ["street", "city", "state", "zip_code"]

# %%
df[['street', 'city', 'state']] = df['purchase_address'].str.split(", ", expand=True)
df[['state', 'zip_code']] = df['state'].str.split(" ", expand=True)
df.head()
# Out:
#   order_id                   product  quantity_ordered  price_each  \
# 0   141234                    iPhone               1.0      700.00
# 1   141235  Lightning Charging Cable               1.0       14.95
# 2   141236          Wired Headphones               2.0       11.99
# 3   141237          27in FHD Monitor               1.0      149.99
# 4   141238          Wired Headphones               1.0       11.99
#
#            order_date                       purchase_address         street  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215  944 Walnut St
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035   185 Maple St
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016   538 Adams St
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001    738 10th St
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301    387 10th St
#
#             city state zip_code
# 0         Boston    MA    02215
# 1       Portland    OR    97035
# 2  San Francisco    CA    94016
# 3    Los Angeles    CA    90001
# 4         Austin    TX    73301

# %% [markdown]
# ### Split order_date to ['year', 'moth', 'day', 'weekday']

# %%
df['year'] = df.order_date.dt.year
df['month'] = df.order_date.dt.month
df['day'] = df.order_date.dt.day
df['weekday'] = df.order_date.dt.day_name() 
df['hour'] = df.order_date.dt.hour
df.head()
# Out:
#   order_id                   product  quantity_ordered  price_each  \
# 0   141234                    iPhone               1.0      700.00
# 1   141235  Lightning Charging Cable               1.0       14.95
# 2   141236          Wired Headphones               2.0       11.99
# 3   141237          27in FHD Monitor               1.0      149.99
# 4   141238          Wired Headphones               1.0       11.99
#
#            order_date                       purchase_address         street  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215  944 Walnut St
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035   185 Maple St
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016   538 Adams St
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001    738 10th St
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301    387 10th St
#
#             city state zip_code  year  month  day   weekday  hour
# 0         Boston    MA    02215  2019      1   22   Tuesday    21
# 1       Portland    OR    97035  2019      1   28    Monday    14
# 2  San Francisco    CA    94016  2019      1   17  Thursday    13
# 3    Los Angeles    CA    90001  2019      1    5  Saturday    20
# 4         Austin    TX    73301  2019      1   25    Friday    11

# %%
df['total_price'] = df.quantity_ordered * df.price_each
df.head()
# Out:
#   order_id                   product  quantity_ordered  price_each  \
# 0   141234                    iPhone               1.0      700.00
# 1   141235  Lightning Charging Cable               1.0       14.95
# 2   141236          Wired Headphones               2.0       11.99
# 3   141237          27in FHD Monitor               1.0      149.99
# 4   141238          Wired Headphones               1.0       11.99
#
#            order_date                       purchase_address         street  \
# 0 2019-01-22 21:25:00        944 Walnut St, Boston, MA 02215  944 Walnut St
# 1 2019-01-28 14:15:00       185 Maple St, Portland, OR 97035   185 Maple St
# 2 2019-01-17 13:33:00  538 Adams St, San Francisco, CA 94016   538 Adams St
# 3 2019-01-05 20:33:00     738 10th St, Los Angeles, CA 90001    738 10th St
# 4 2019-01-25 11:59:00          387 10th St, Austin, TX 73301    387 10th St
#
#             city state zip_code  year  month  day   weekday  hour  total_price
# 0         Boston    MA    02215  2019      1   22   Tuesday    21       700.00
# 1       Portland    OR    97035  2019      1   28    Monday    14        14.95
# 2  San Francisco    CA    94016  2019      1   17  Thursday    13        23.98
# 3    Los Angeles    CA    90001  2019      1    5  Saturday    20       149.99
# 4         Austin    TX    73301  2019      1   25    Friday    11        11.99

# %%
df.columns
new_ordered_col = [
    'order_id', 'product', 'quantity_ordered', 'price_each', 'total_price',
    'order_date', 'month', 'day', 'weekday', 'hour',
    'purchase_address', 'street', 'city', 'state', 'zip_code', 'year'
    ]

df = df[new_ordered_col]
df.head()
# Out:
#   order_id                   product  quantity_ordered  price_each  \
# 0   141234                    iPhone               1.0      700.00
# 1   141235  Lightning Charging Cable               1.0       14.95
# 2   141236          Wired Headphones               2.0       11.99
# 3   141237          27in FHD Monitor               1.0      149.99
# 4   141238          Wired Headphones               1.0       11.99
#
#    total_price          order_date  month  day   weekday  hour  \
# 0       700.00 2019-01-22 21:25:00      1   22   Tuesday    21
# 1        14.95 2019-01-28 14:15:00      1   28    Monday    14
# 2        23.98 2019-01-17 13:33:00      1   17  Thursday    13
# 3       149.99 2019-01-05 20:33:00      1    5  Saturday    20
# 4        11.99 2019-01-25 11:59:00      1   25    Friday    11
#
#                         purchase_address         street           city state  \
# 0        944 Walnut St, Boston, MA 02215  944 Walnut St         Boston    MA
# 1       185 Maple St, Portland, OR 97035   185 Maple St       Portland    OR
# 2  538 Adams St, San Francisco, CA 94016   538 Adams St  San Francisco    CA
# 3     738 10th St, Los Angeles, CA 90001    738 10th St    Los Angeles    CA
# 4          387 10th St, Austin, TX 73301    387 10th St         Austin    TX
#
#   zip_code  year
# 0    02215  2019
# 1    97035  2019
# 2    94016  2019
# 3    90001  2019
# 4    73301  2019

# %%
df = df.sort_values(by=['order_date'])
# df.to_csv("cleaned_data.csv", index=False)

# %%
df.head()
# Out:
#      order_id                   product  quantity_ordered  price_each  \
# 6344   147268          Wired Headphones               1.0       11.99
# 7154   148041      USB-C Charging Cable               1.0       11.95
# 8507   149343  Apple Airpods Headphones               1.0      150.00
# 9161   149964    AAA Batteries (4-pack)               1.0        2.99
# 8514   149350      USB-C Charging Cable               2.0       11.95
#
#       total_price          order_date  month  day  weekday  hour  \
# 6344        11.99 2019-01-01 03:07:00      1    1  Tuesday     3
# 7154        11.95 2019-01-01 03:40:00      1    1  Tuesday     3
# 8507       150.00 2019-01-01 04:56:00      1    1  Tuesday     4
# 9161         2.99 2019-01-01 05:53:00      1    1  Tuesday     5
# 8514        23.90 2019-01-01 06:03:00      1    1  Tuesday     6
#
#                             purchase_address         street           city  \
# 6344      9 Lake St, New York City, NY 10001      9 Lake St  New York City
# 7154  760 Church St, San Francisco, CA 94016  760 Church St  San Francisco
# 8507     735 5th St, New York City, NY 10001     735 5th St  New York City
# 9161         75 Jackson St, Dallas, TX 75001  75 Jackson St         Dallas
# 8514           943 2nd St, Atlanta, GA 30301     943 2nd St        Atlanta
#
#      state zip_code  year
# 6344    NY    10001  2019
# 7154    CA    94016  2019
# 8507    NY    10001  2019
# 9161    TX    75001  2019
# 8514    GA    30301  2019
